# %% [markdown]
# # Lab 01 - Introduction and Basic Concepts
#
# Welcome to Lab 01 of the Alura-PortoSeguro course!
#
# ## Objectives
# - Understand basic Python concepts
# - Work with data structures
# - Practice fundamental operations

# %% [markdown]
# ## Exercise 1: Hello World
#
# Let's start with a simple Hello World example.

# %%
# Your code here
print("Hello, Alura-PortoSeguro!")

# %% [markdown]
# ## Exercise 2: Working with Variables
#
# Practice variable declaration and basic operations.

# %%
# Define variables
name = "Student"
age = 25
height = 1.75

# Display information
print(f"Name: {name}")
print(f"Age: {age}")
print(f"Height: {height}m")

# %% [markdown]
# ## Exercise 3: Lists and Loops
#
# Work with Python lists and iteration.

# %%
# Create a list of numbers
numbers = [1, 2, 3, 4, 5]

# Calculate sum
total = sum(numbers)
print(f"Sum of numbers: {total}")

# Iterate through the list
for num in numbers:
    print(f"Number: {num}, Square: {num**2}")

# %% [markdown]
# ## Conclusion
#
# Great job completing Lab 01! You've learned:
# - Basic Python syntax
# - Variable operations
# - Working with lists and loops
#
# Continue to Lab 02 for more advanced topics!
